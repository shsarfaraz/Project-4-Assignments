# %% [markdown]
# <a href="https://colab.research.google.com/github/shsarfaraz/Project-4-Assignments/blob/master/02_intermediate_Control_Flow_for_Console.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("handout\nHigh Low Game\n")

round = 5

def main():
  print("Welcome to the High Low Game 😊")
  print("********************************")

  your_score = 0
  for i in range(round):
    print("Round", 1 + i)
    print("Your Score: " + str(your_score))

    computer_number = random.randint(1, 100)
    your_number = random.randint(1, 100)

    print("Your Number is: ", your_number)

    choice: str = input("Do you think your number is higher or lower than the computer's number? ")
    higher_and_correct : bool = choice == "higher" and your_number > computer_number
    lower_and_correct : bool = choice == "lower" and your_number < computer_number

    if higher_and_correct or lower_and_correct:
      print ("You'r right! The Computer\'s Number was ", computer_number)
      your_score += 1
    else:
      print("You're wrong! The Computer\'s Number was ", computer_number)

    print("Your score is now ",your_score)
    print()

  print("Thanks for Playing!")

if __name__ == "__main__":
  main()
# Out:
# handout
# High Low Game
#
# Welcome to the High Low Game 😊
# ********************************
# Round 1
# Your Score: 0
# Your Number is:  21
# Do you think your number is higher or lower than the computer's number? lower
# You'r right! The Computer's Number was  37
# Your score is now  1
#
# Round 2
# Your Score: 1
# Your Number is:  99
# Do you think your number is higher or lower than the computer's number? higher
# You'r right! The Computer's Number was  29
# Your score is now  2
#
# Round 3
# Your Score: 2
# Your Number is:  32
# Do you think your number is higher or lower than the computer's number? lower
# You'r right! The Computer's Number was  89
# Your score is now  3
#
# Round 4
# Your Score: 3
# Your Number is:  85
# Do you think your number is higher or lower than the computer's number? higher
# You'r right! The Computer's Number was  63
# Your score is now  4
#
# Round 5
# Your Score: 4
# Your Number is:  49
# ...

# %%
print("Intro to Python / handout.\n")
print("Planetary Weight Calculator\n")

print("Welcome to the Planetary Weight Calculator!")
print("******************************************")

def main():

  earth_weight = float(input("Enter your weight on Earth: "))
  gravity_ratios = {
    "Mercury": 0.38,
    "Venus": 0.91,
    "Mars": 0.38,
    "Jupiter": 2.34,
    "Saturn": 0.93,
    "Uranus": 0.92,
    "Neptune": 1.19
}

  print("\nSelect a planet to calculate your weight on: ")
  for planet in gravity_ratios:
    print(f" - {planet}")
  planet_choice = input("Enter the name of the planet: ").title()

  if planet_choice in gravity_ratios:
    new_weight = gravity_ratios[planet_choice]
    planetary_weight = earth_weight * new_weight
    print(f"Your weight on {planet_choice} is approximately {planetary_weight:.2f} kg.")
  else:
    print("Invalid Choice")

if __name__ == "__main__":
  main()
# Out:
# Intro to Python / handout.
#
# Planetary Weight Calculator
#
# Welcome to the Planetary Weight Calculator!
# ******************************************
# Enter your weight on Earth: 65
#
# Select a planet to calculate your weight on:
#  - Mercury
#  - Venus
#  - Mars
#  - Jupiter
#  - Saturn
#  - Uranus
#  - Neptune
# Enter the name of the planet: mars
# Your weight on Mars is approximately 24.70 kg.

# %%
print("Lists and Dicts/handout\n")
print("List Practice\n")

# Corrected list to separate items
my_list = ["Apple", "Banana", "Cherry", "Mango", "Orange", "Pear", "Peach"]
print("Current List:", my_list)

def access_element(my_list, index):
    """Returns the element at the given index in the list."""
    if 0 <= index < len(my_list):
        return f"Element at index {index}: {my_list[index]}"
    else:
        return "Index out of range"

def modify_element(my_list, index, new_value):
    """Modifies the element at the given index in the list."""
    if 0 <= index < len(my_list):
        old_value = my_list[index]
        my_list[index] = new_value
        return f"Element at index {index} modified from {old_value} to {new_value}"
    else:
        return "Index out of range"

def slice_list(my_list, start, end):
    """Returns a new list containing the elements from the start index to the end index."""
    if 0 <= start <= end < len(my_list):
        return f"Sliced List: {my_list[start:end]}"
    else:
        return "Invalid slice indices"

def list_game():
    print("\nWelcome to the List Manipulation Game!")

    while True:
        print("\nCurrent List:", my_list)

        print("Select an Operation: ")
        print("1. Access Element")
        print("2. Modify Element")
        print("3. Slice List")
        print("4. Quit")

        choice = input("Enter your choice (1-4): ")

        if choice == "1":
            index = int(input("Enter the index of the element you want to access: "))
            result = access_element(my_list, index)
            print(result)

        elif choice == "2":
            index = int(input("Enter the index of the element you want to modify: "))
            new_value = input("Enter the new value for the element: ")
            result = modify_element(my_list, index, new_value)
            print(result)

        elif choice == "3":
            start = int(input("Enter the start index for the slice: "))
            end = int(input("Enter the end index for the slice: "))
            result = slice_list(my_list, start, end)
            print(result)

        elif choice == "4":
            print("You exited the game. Thanks for playing!")
            break

        else:
            print("Invalid Choice, Please Enter a Number Between 1-4")

if __name__ == "__main__":
    list_game()
# Out:
# Lists and Dicts/handout
#
# List Practice
#
# Current List: ['Apple', 'Banana', 'Cherry', 'Mango', 'Orange', 'Pear', 'Peach']
#
# Welcome to the List Manipulation Game!
#
# Current List: ['Apple', 'Banana', 'Cherry', 'Mango', 'Orange', 'Pear', 'Peach']
# Select an Operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 1
# Enter the index of the element you want to access: 1
# Element at index 1: Banana
#
# Current List: ['Apple', 'Banana', 'Cherry', 'Mango', 'Orange', 'Pear', 'Peach']
# Select an Operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 2
# Enter the index of the element you want to modify: 1
# Enter the new value for the element: Bhindi
# Element at index 1 modified from Banana to Bhindi
#
# Current List: ['Apple', 'Bhindi', 'Cherry', 'Mango', 'Orange', 'Pear', 'Peach']
# Select an Operation:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# ...
